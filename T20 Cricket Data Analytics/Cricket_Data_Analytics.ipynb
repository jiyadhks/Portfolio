# %%
#Importing the libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Getting the URL of the site and extracting the contents

url="https://www.espncricinfo.com/records/tournament/team-match-results/icc-men-s-t20-world-cup-2022-23-14450"

page = requests.get(url)

soup = BeautifulSoup(page.text,"html")

# %%
#Getting the table contents

table=soup.find_all("table")[0]

# %%
#Extracting the portion that contains the table title

table_titles=table.find_all('td')[:7]

# %%
#Getting the table titles

table_titles=[title.text.strip() for title in table_titles]

# %%
#Display table titles

print(table_titles)
# Out:
# ['Team 1', 'Team 2', 'Winner', 'Margin', 'Ground', 'Match Date', 'Scorecard']

# %%
#creating the DataFrame for match summary

df_match_summary=pd.DataFrame(columns=table_titles)
df_match_summary
# Out:
# Empty DataFrame
# Columns: [Team 1, Team 2, Winner, Margin, Ground, Match Date, Scorecard]
# Index: []

# %%
#Extracting the html content to get the column data

column_data=table.find_all("tr")[1:]

# %%
#Extracting the values row wise

#Link and match_id's of all matches
scorecard_links={}

#Extracting the data and adding into the dataframe
for row in column_data:
    td_data=row.find_all("td")
    table_data=[data.text.strip() for data in td_data]
    scorecard_link ="https://www.espncricinfo.com"+row.find_all("a")[-1]["href"]
    match_id=row.find_all("a")[1].text.strip()
    scorecard_links[match_id]=scorecard_link
    length=len(df_match_summary)
    df_match_summary.loc[length]=table_data

# %%
#dataframe

df_match_summary
# Out:
#          Team 1       Team 2       Winner      Margin     Ground  \
# 0       Namibia    Sri Lanka      Namibia     55 runs    Geelong
# 1   Netherlands       U.A.E.  Netherlands   3 wickets    Geelong
# 2      Scotland  West Indies     Scotland     42 runs     Hobart
# 3       Ireland     Zimbabwe     Zimbabwe     31 runs     Hobart
# 4       Namibia  Netherlands  Netherlands   5 wickets    Geelong
# ..          ...          ...          ...         ...        ...
# 79   Bangladesh     Pakistan     Pakistan   5 wickets   Adelaide
# 80        India     Zimbabwe        India     71 runs  Melbourne
# 81  New Zealand     Pakistan     Pakistan   7 wickets     Sydney
# 82      England        India      England  10 wickets   Adelaide
# 83      England     Pakistan      England   5 wickets  Melbourne
#
#       Match Date    Scorecard
# 0   Oct 16, 2022  T20I # 1823
# 1   Oct 16, 2022  T20I # 1825
# 2   Oct 17, 2022  T20I # 1826
# 3   Oct 17, 2022  T20I # 1828
# 4   Oct 18, 2022  T20I # 1830
# ..           ...          ...
# 79   Nov 6, 2022  T20I # 1872
# 80   Nov 6, 2022  T20I # 1873
# 81   Nov 9, 2022  T20I # 1877
# 82  Nov 10, 2022  T20I # 1878
# 83  Nov 13, 2022  T20I # 1879
#
# [84 rows x 7 columns]

# %%
#Changing the column name scorecard to ID

df_match_summary.rename({"Scorecard":"match_id"},axis=1,inplace=True)

# %%
#checking for any null values in the dataframe

df_match_summary.isna().sum()
# Out:
# Team 1        0
# Team 2        0
# Winner        0
# Margin        0
# Ground        0
# Match Date    0
# match_id      0
# dtype: int64

# %%
#Saving the file to csv

df_match_summary.to_csv(r"Data\match_summary.csv",index=False)

# %%
#Extracting the batting summary for each of the matches

df_batting_summary=pd.DataFrame(columns=["match","teamInnings","battingPos","batsman_name","dismissal","runs","balls","minutes","4s","6s","SR","player_link","match_id"])
#df_batting_summary=[data.text.strip() for data in table1.find_all("tr")[0]]
#df_batting_summary=["match","teamInnings","battingPos"]+df_batting_summary
#df_batting_summary=pd.DataFrame(columns=df_batting_summary)

#scorecard_links={"T20I # 1823":"https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/namibia-vs-sri-lanka-1st-match-first-round-group-a-1298135/full-scorecard"}

#Looping through each link to get the scorecard of all matches
for match_id,link in scorecard_links.items():
    page = requests.get(link)
    soup = BeautifulSoup(page.text,"html")
    table1=soup.find_all("table")[0]
    table2=soup.find_all("table")[2]
    outer_span1=soup.find('span', class_='ds-inline-flex ds-items-center ds-bg-ui-fill ds-text-typo-primary ds-border ds-border-ui-stroke-primary ds-h-6 ds-px-2 ds-rounded-full ds-font-medium ds-cursor-pointer ds-whitespace-nowrap')
    outer_span2=soup.find('span',class_='ds-inline-flex ds-items-center ds-bg-ui-fill-alternate ds-text-typo ds-h-6 ds-px-2 ds-rounded-full ds-font-medium ds-cursor-pointer ds-whitespace-nowrap')
    inner_span1 = outer_span1.find('span', class_='ds-text-tight-xs')
    inner_span2 = outer_span2.find('span', class_='ds-text-tight-xs')
    team1 = inner_span1.text.replace("Innings"," ").strip()
    team2 = inner_span2.text.replace("Innings"," ").strip()


    batting_pos=0
    column_data=table1.find_all("tr")[1:]
    for row in column_data:
        if '<td class="ds-min-w-max" colspan="1">Extras</td>' in str(row):
            break

        elif '<tr class="ds-hidden"><td class="" colspan="9"></td></tr>' in str(row):
            continue
        else:
            batting_pos=batting_pos+1
            table_data=[team1+" Vs "+team2,team1,batting_pos]
            row_data=row.find_all("td")
            table_data1=[data.text for data in row_data]
            player_link="https://www.espncricinfo.com"+row.find('a')['href']
            table_data=table_data+table_data1+[player_link]+[match_id]
            length=len(df_batting_summary)
            df_batting_summary.loc[length]=table_data
            

    batting_pos=0
    column_data=table2.find_all("tr")[1:]
    for row in column_data:
        if '<td class="ds-min-w-max" colspan="1">Extras</td>' in str(row):
            break

        elif '<tr class="ds-hidden"><td class="" colspan="9"></td></tr>' in str(row):
            continue
        else:
            batting_pos=batting_pos+1
            table_data=[team1+" Vs "+team2,team2,batting_pos]
            row_data=row.find_all("td")
            table_data1=[data.text for data in row_data]
            player_link="https://www.espncricinfo.com"+row.find('a')['href']
            table_data=table_data+table_data1+[player_link]+[match_id]
            length=len(df_batting_summary)
            df_batting_summary.loc[length]=table_data

df_batting_summary
# Out:
#                     match teamInnings  battingPos             batsman_name  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus (c)
# ..                    ...         ...         ...                      ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#                                dismissal runs balls minutes 4s 6s      SR  \
# 0           c Pramod Madushan b Chameera    3     6       7  0  0   50.00
# 1            c Shanaka b Pramod Madushan    9     9      15  1  0  100.00
# 2                c †Mendis b Karunaratne   20    12      18  1  2  166.66
# 3        c DM de Silva b Pramod Madushan   26    24      49  2  0  108.33
# 4           c Gunathilaka b PWH de Silva   20    24      30  0  0   83.33
# ..                                   ...  ...   ...     ... .. ..     ...
# 694        c Iftikhar Ahmed b Haris Rauf   10     9      16  2  0  111.11
# 695                             not out    52    49      81  5  1  106.12
# 696  c Shaheen Shah Afridi b Shadab Khan   20    23      36  1  0   86.95
# 697                     b Mohammad Wasim   19    13      30  3  0  146.15
# 698                             not out     1     1       3  0  0  100.00
#
#                                            player_link     match_id
# 0    https://www.espncricinfo.com/cricketers/michae...  T20I # 1823
# 1    https://www.espncricinfo.com/cricketers/divan-...  T20I # 1823
# 2    https://www.espncricinfo.com/cricketers/jan-ni...  T20I # 1823
# 3    https://www.espncricinfo.com/cricketers/stepha...  T20I # 1823
# 4    https://www.espncricinfo.com/cricketers/gerhar...  T20I # 1823
# ..                                                 ...          ...
# 694  https://www.espncricinfo.com/cricketers/phil-s...  T20I # 1879
# 695  https://www.espncricinfo.com/cricketers/ben-st...  T20I # 1879
# 696  https://www.espncricinfo.com/cricketers/harry-...  T20I # 1879
# 697  https://www.espncricinfo.com/cricketers/moeen-...  T20I # 1879
# 698  https://www.espncricinfo.com/cricketers/liam-l...  T20I # 1879
#
# [699 rows x 13 columns]

# %%
#Replacing the "\" and unwanted values present in the columns

def replace_after_backslash(value):
    backslash_index = value.find('\xa0')
    return value[:backslash_index] if backslash_index != -1 else value
    
def replace_between_backslash(value):
    value=value.replace("†","")
    return(value)

df_batting_summary['batsman_name'] = df_batting_summary['batsman_name'].apply(lambda x: replace_after_backslash(x))
df_batting_summary['dismissal']=df_batting_summary['dismissal'].apply(lambda x: replace_between_backslash(x))
df_batting_summary
# Out:
#                     match teamInnings  battingPos            batsman_name  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#                                dismissal runs balls minutes 4s 6s      SR  \
# 0           c Pramod Madushan b Chameera    3     6       7  0  0   50.00
# 1            c Shanaka b Pramod Madushan    9     9      15  1  0  100.00
# 2                 c Mendis b Karunaratne   20    12      18  1  2  166.66
# 3        c DM de Silva b Pramod Madushan   26    24      49  2  0  108.33
# 4           c Gunathilaka b PWH de Silva   20    24      30  0  0   83.33
# ..                                   ...  ...   ...     ... .. ..     ...
# 694        c Iftikhar Ahmed b Haris Rauf   10     9      16  2  0  111.11
# 695                             not out    52    49      81  5  1  106.12
# 696  c Shaheen Shah Afridi b Shadab Khan   20    23      36  1  0   86.95
# 697                     b Mohammad Wasim   19    13      30  3  0  146.15
# 698                             not out     1     1       3  0  0  100.00
#
#                                            player_link     match_id
# 0    https://www.espncricinfo.com/cricketers/michae...  T20I # 1823
# 1    https://www.espncricinfo.com/cricketers/divan-...  T20I # 1823
# 2    https://www.espncricinfo.com/cricketers/jan-ni...  T20I # 1823
# 3    https://www.espncricinfo.com/cricketers/stepha...  T20I # 1823
# 4    https://www.espncricinfo.com/cricketers/gerhar...  T20I # 1823
# ..                                                 ...          ...
# 694  https://www.espncricinfo.com/cricketers/phil-s...  T20I # 1879
# 695  https://www.espncricinfo.com/cricketers/ben-st...  T20I # 1879
# 696  https://www.espncricinfo.com/cricketers/harry-...  T20I # 1879
# 697  https://www.espncricinfo.com/cricketers/moeen-...  T20I # 1879
# 698  https://www.espncricinfo.com/cricketers/liam-l...  T20I # 1879
#
# [699 rows x 13 columns]

# %%
#Creating a new column to find whether the batsman is out or not

df_batting_summary["out/not_out"]=df_batting_summary["dismissal"].apply(lambda x : "not out" if x=="not out " else "out")

# %%
#droppiing the dismissal column

df_batting_summary.drop(columns=["dismissal"],inplace=True)
df_batting_summary
# Out:
#                     match teamInnings  battingPos            batsman_name  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#     runs balls minutes 4s 6s      SR  \
# 0      3     6       7  0  0   50.00
# 1      9     9      15  1  0  100.00
# 2     20    12      18  1  2  166.66
# 3     26    24      49  2  0  108.33
# 4     20    24      30  0  0   83.33
# ..   ...   ...     ... .. ..     ...
# 694   10     9      16  2  0  111.11
# 695   52    49      81  5  1  106.12
# 696   20    23      36  1  0   86.95
# 697   19    13      30  3  0  146.15
# 698    1     1       3  0  0  100.00
#
#                                            player_link     match_id
# 0    https://www.espncricinfo.com/cricketers/michae...  T20I # 1823
# 1    https://www.espncricinfo.com/cricketers/divan-...  T20I # 1823
# 2    https://www.espncricinfo.com/cricketers/jan-ni...  T20I # 1823
# 3    https://www.espncricinfo.com/cricketers/stepha...  T20I # 1823
# 4    https://www.espncricinfo.com/cricketers/gerhar...  T20I # 1823
# ..                                                 ...          ...
# 694  https://www.espncricinfo.com/cricketers/phil-s...  T20I # 1879
# 695  https://www.espncricinfo.com/cricketers/ben-st...  T20I # 1879
# 696  https://www.espncricinfo.com/cricketers/harry-...  T20I # 1879
# 697  https://www.espncricinfo.com/cricketers/moeen-...  T20I # 1879
# 698  https://www.espncricinfo.com/cricketers/liam-l...  T20I # 1879
#
# [699 rows x 12 columns]

# %%
#dataframe info

df_batting_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 698
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   match         699 non-null    object
#  1   teamInnings   699 non-null    object
#  2   battingPos    699 non-null    int64
#  3   batsman_name  699 non-null    object
#  4   runs          699 non-null    object
#  5   balls         699 non-null    object
#  6   minutes       699 non-null    object
#  7   4s            699 non-null    object
#  8   6s            699 non-null    object
#  9   SR            699 non-null    object
#  10  player_link   699 non-null    object
#  11  match_id      699 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 71.0+ KB

# %%
#Creating a new dataframe for player info

df_player_info1=df_batting_summary[["batsman_name","teamInnings","player_link"]]
df_player_info1.rename({"batsman_name":"name","teamInnings":"team"},axis=1,inplace=True)
df_player_info1
# Out:
#                        name     team  \
# 0        Michael van Lingen  Namibia
# 1             Divan la Cock  Namibia
# 2    Jan Nicol Loftie-Eaton  Namibia
# 3             Stephan Baard  Namibia
# 4           Gerhard Erasmus  Namibia
# ..                      ...      ...
# 694               Phil Salt  England
# 695              Ben Stokes  England
# 696             Harry Brook  England
# 697               Moeen Ali  England
# 698        Liam Livingstone  England
#
#                                            player_link
# 0    https://www.espncricinfo.com/cricketers/michae...
# 1    https://www.espncricinfo.com/cricketers/divan-...
# 2    https://www.espncricinfo.com/cricketers/jan-ni...
# 3    https://www.espncricinfo.com/cricketers/stepha...
# 4    https://www.espncricinfo.com/cricketers/gerhar...
# ..                                                 ...
# 694  https://www.espncricinfo.com/cricketers/phil-s...
# 695  https://www.espncricinfo.com/cricketers/ben-st...
# 696  https://www.espncricinfo.com/cricketers/harry-...
# 697  https://www.espncricinfo.com/cricketers/moeen-...
# 698  https://www.espncricinfo.com/cricketers/liam-l...
#
# [699 rows x 3 columns]

# %%
#dropping the link column from the batting summary dataframe

df_batting_summary.drop(columns=["player_link"],inplace=True)

# %%
#Saving the csv file

df_batting_summary.to_csv(r"Data\batting_summary.csv",index=False)

# %%
#bowling summary

#link='https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard'

df_bowling_summary=pd.DataFrame(columns=["match","bowlingTeam","bowlerName","overs","maiden","runs","wickets","economy","0s","4s","6s","wides","noBalls","player_link","match_id"])
#df_batting_summary=[data.text.strip() for data in table1.find_all("tr")[0]]
#df_batting_summary=["match","teamInnings","battingPos"]+df_batting_summary
#df_batting_summary=pd.DataFrame(columns=df_batting_summary)

#Looping through each link to get the scorecard of all matches
for match_id,link in scorecard_links.items():  
    page = requests.get(link)
    soup = BeautifulSoup(page.text,"html")
    table1=soup.find_all("table")[1]
    table2=soup.find_all("table")[3]
    outer_span1=soup.find('span',class_='ds-inline-flex ds-items-center ds-bg-ui-fill-alternate ds-text-typo ds-h-6 ds-px-2 ds-rounded-full ds-font-medium ds-cursor-pointer ds-whitespace-nowrap')                                     
    outer_span2=soup.find('span', class_='ds-inline-flex ds-items-center ds-bg-ui-fill ds-text-typo-primary ds-border ds-border-ui-stroke-primary ds-h-6 ds-px-2 ds-rounded-full ds-font-medium ds-cursor-pointer ds-whitespace-nowrap')
    inner_span1 = outer_span1.find('span', class_='ds-text-tight-xs')
    inner_span2 = outer_span2.find('span', class_='ds-text-tight-xs')
    team1 = inner_span1.text.replace("Innings"," ").strip()
    team2 = inner_span2.text.replace("Innings"," ").strip()


    column_data=table1.find_all("tr")[1:]
    for row in column_data:
        if '<td class="" colspan="11">' in str(row):
                continue
        else:
            table_data=[team1+" Vs "+team2,team1]
            row_data=row.find_all("td")
            table_data1=[data.text for data in row_data]
            player_link="https://www.espncricinfo.com"+row.find('a')['href']
            table_data=table_data+table_data1+[player_link]+[match_id]
            length=len(df_bowling_summary)
            df_bowling_summary.loc[length]=table_data                           


    column_data=table2.find_all("tr")[1:]
    for row in column_data:
        if '<td class="" colspan="11">' in str(row):
                continue
        else:
            table_data=[team1+" Vs "+team2,team2]
            row_data=row.find_all("td")
            table_data1=[data.text for data in row_data]
            player_link="https://www.espncricinfo.com"+row.find('a')['href']
            table_data=table_data+table_data1+[player_link]+[match_id]
            length=len(df_bowling_summary)
            df_bowling_summary.loc[length]=table_data                           

df_bowling_summary
# Out:
#                     match bowlingTeam           bowlerName overs maiden runs  \
# 0    Sri Lanka Vs Namibia   Sri Lanka   Maheesh Theekshana     4      0   23
# 1    Sri Lanka Vs Namibia   Sri Lanka  Dushmantha Chameera     4      0   39
# 2    Sri Lanka Vs Namibia   Sri Lanka      Pramod Madushan     4      0   37
# 3    Sri Lanka Vs Namibia   Sri Lanka  Chamika Karunaratne     4      0   36
# 4    Sri Lanka Vs Namibia   Sri Lanka    Wanindu Hasaranga     4      0   27
# ..                    ...         ...                  ...   ...    ...  ...
# 495   England Vs Pakistan    Pakistan          Naseem Shah     4      0   30
# 496   England Vs Pakistan    Pakistan           Haris Rauf     4      0   23
# 497   England Vs Pakistan    Pakistan          Shadab Khan     4      0   20
# 498   England Vs Pakistan    Pakistan       Mohammad Wasim     4      0   38
# 499   England Vs Pakistan    Pakistan       Iftikhar Ahmed   0.5      0   13
#
#     wickets economy  0s 4s 6s wides noBalls  \
# 0         1    5.75   7  0  0     2       0
# 1         1    9.75   6  3  1     2       0
# 2         2    9.25   6  3  1     0       0
# 3         1    9.00   7  3  1     1       0
# 4         1    6.75   8  1  1     0       0
# ..      ...     ...  .. .. ..   ...     ...
# 495       0    7.50  15  3  1     1       0
# 496       2    5.75  13  3  0     1       0
# 497       1    5.00  10  1  0     0       0
# 498       1    9.50   5  5  0     2       0
# 499       0   15.60   0  1  1     0       0
#
#                                            player_link     match_id
# 0    https://www.espncricinfo.com/cricketers/mahees...  T20I # 1823
# 1    https://www.espncricinfo.com/cricketers/dushma...  T20I # 1823
# 2    https://www.espncricinfo.com/cricketers/pramod...  T20I # 1823
# 3    https://www.espncricinfo.com/cricketers/chamik...  T20I # 1823
# 4    https://www.espncricinfo.com/cricketers/wanind...  T20I # 1823
# ..                                                 ...          ...
# 495  https://www.espncricinfo.com/cricketers/naseem...  T20I # 1879
# 496  https://www.espncricinfo.com/cricketers/haris-...  T20I # 1879
# 497  https://www.espncricinfo.com/cricketers/shadab...  T20I # 1879
# 498  https://www.espncricinfo.com/cricketers/mohamm...  T20I # 1879
# 499  https://www.espncricinfo.com/cricketers/iftikh...  T20I # 1879
#
# [500 rows x 15 columns]

# %%
#renaming the bowling summary columns and adding the player details to the player info dataframe

df_player_info2=df_bowling_summary[["bowlerName","bowlingTeam","player_link"]]
df_player_info2.rename({"bowlerName":"name","bowlingTeam":"team"},axis=1,inplace=True)
df_player_info=pd.concat([df_player_info1,df_player_info2])
df_player_info
# Out:
#                        name      team  \
# 0        Michael van Lingen   Namibia
# 1             Divan la Cock   Namibia
# 2    Jan Nicol Loftie-Eaton   Namibia
# 3             Stephan Baard   Namibia
# 4           Gerhard Erasmus   Namibia
# ..                      ...       ...
# 495             Naseem Shah  Pakistan
# 496              Haris Rauf  Pakistan
# 497             Shadab Khan  Pakistan
# 498          Mohammad Wasim  Pakistan
# 499          Iftikhar Ahmed  Pakistan
#
#                                            player_link
# 0    https://www.espncricinfo.com/cricketers/michae...
# 1    https://www.espncricinfo.com/cricketers/divan-...
# 2    https://www.espncricinfo.com/cricketers/jan-ni...
# 3    https://www.espncricinfo.com/cricketers/stepha...
# 4    https://www.espncricinfo.com/cricketers/gerhar...
# ..                                                 ...
# 495  https://www.espncricinfo.com/cricketers/naseem...
# 496  https://www.espncricinfo.com/cricketers/haris-...
# 497  https://www.espncricinfo.com/cricketers/shadab...
# 498  https://www.espncricinfo.com/cricketers/mohamm...
# 499  https://www.espncricinfo.com/cricketers/iftikh...
#
# [1199 rows x 3 columns]

# %%
#dropping the player link column from the bowling summary dataframe

df_bowling_summary.drop(columns=["player_link"],inplace=True)

# %%
#saving the bowling summary file

df_bowling_summary.to_csv(r"Data\bowling_summary.csv",index=False)

# %%
#dropping the duplicates

df_player_info.drop_duplicates(subset="name",keep="first",inplace=True)
df_player_info.reset_index(drop=True,inplace=True)

# %%
#Adding the battingstyle,bowlingstyle and playingrole column to the palyer info dataframe

df_player_info=pd.concat([df_player_info,pd.DataFrame(columns=["battingStyle","bowlingStyle","playingRole"])])
df_player_info
# Out:
#                        name         team  \
# 0        Michael van Lingen      Namibia
# 1             Divan la Cock      Namibia
# 2    Jan Nicol Loftie-Eaton      Namibia
# 3             Stephan Baard      Namibia
# 4           Gerhard Erasmus      Namibia
# ..                      ...          ...
# 208             Ashton Agar    Australia
# 209          Brandon Glover  Netherlands
# 210          Shoriful Islam   Bangladesh
# 211          Ebadot Hossain   Bangladesh
# 212            Chris Jordan      England
#
#                                            player_link battingStyle  \
# 0    https://www.espncricinfo.com/cricketers/michae...          NaN
# 1    https://www.espncricinfo.com/cricketers/divan-...          NaN
# 2    https://www.espncricinfo.com/cricketers/jan-ni...          NaN
# 3    https://www.espncricinfo.com/cricketers/stepha...          NaN
# 4    https://www.espncricinfo.com/cricketers/gerhar...          NaN
# ..                                                 ...          ...
# 208  https://www.espncricinfo.com/cricketers/ashton...          NaN
# 209  https://www.espncricinfo.com/cricketers/brando...          NaN
# 210  https://www.espncricinfo.com/cricketers/shorif...          NaN
# 211  https://www.espncricinfo.com/cricketers/ebadot...          NaN
# 212  https://www.espncricinfo.com/cricketers/chris-...          NaN
#
#     bowlingStyle playingRole
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ..           ...         ...
# 208          NaN         NaN
# 209          NaN         NaN
# 210          NaN         NaN
# 211          NaN         NaN
# 212          NaN         NaN
#
# [213 rows x 6 columns]

# %%
#extarcting the battingstyle, bowlingstyle and playingrole values from the website

table_list=[]
players_info_extracted=pd.DataFrame(columns=["battingStyle","bowlingStyle","playingRole"])
links='https://www.espncricinfo.com/cricketers/matthew-wade-230193'

#for link in [links]:
for link in df_player_info["player_link"]:
    table_list=[]
    flag=0
    page = requests.get(link)
    soup = BeautifulSoup(page.text,"html")
    player_outer=soup.find("div",class_="ds-grid lg:ds-grid-cols-3 ds-grid-cols-2 ds-gap-4 ds-mb-8")
    for row in player_outer:
        if row.find("p").text.strip()== "Batting Style":
            table_list.append(row.find("span").text.strip())
        elif row.find("p").text.strip()== "Bowling Style":
            flag=1
            table_list.append(row.find("span").text.strip())
        elif row.find("p").text.strip()== "Playing Role":
            table_list.append(row.find("span").text.strip())
        else:
            pass
    if flag==0:
        table_list.insert(1,"")
    length=len(players_info_extracted)
    players_info_extracted.loc[length]=table_list
    
players_info_extracted
# Out:
#        battingStyle                             bowlingStyle  \
# 0     Left hand Bat  Left arm Medium, Slow Left arm Orthodox
# 1    Right hand Bat                                 Legbreak
# 2     Left hand Bat               Right arm Medium, Legbreak
# 3    Right hand Bat                    Right arm Medium fast
# 4    Right hand Bat                       Right arm Offbreak
# ..              ...                                      ...
# 208   Left hand Bat                   Slow Left arm Orthodox
# 209  Right hand Bat                           Right arm Fast
# 210   Left hand Bat                     Left arm Medium fast
# 211  Right hand Bat                    Right arm Fast medium
# 212  Right hand Bat                    Right arm Fast medium
#
#             playingRole
# 0    Bowling Allrounder
# 1        Opening Batter
# 2                Batter
# 3                Batter
# 4            Allrounder
# ..                  ...
# 208              Bowler
# 209              Bowler
# 210              Bowler
# 211              Bowler
# 212              Bowler
#
# [213 rows x 3 columns]

# %%
#assigning the extratced values to the playerinfo dataframe

df_player_info[["battingStyle","bowlingStyle","playingRole"]]=players_info_extracted
df_player_info
# Out:
#                        name         team  \
# 0        Michael van Lingen      Namibia
# 1             Divan la Cock      Namibia
# 2    Jan Nicol Loftie-Eaton      Namibia
# 3             Stephan Baard      Namibia
# 4           Gerhard Erasmus      Namibia
# ..                      ...          ...
# 208             Ashton Agar    Australia
# 209          Brandon Glover  Netherlands
# 210          Shoriful Islam   Bangladesh
# 211          Ebadot Hossain   Bangladesh
# 212            Chris Jordan      England
#
#                                            player_link    battingStyle  \
# 0    https://www.espncricinfo.com/cricketers/michae...   Left hand Bat
# 1    https://www.espncricinfo.com/cricketers/divan-...  Right hand Bat
# 2    https://www.espncricinfo.com/cricketers/jan-ni...   Left hand Bat
# 3    https://www.espncricinfo.com/cricketers/stepha...  Right hand Bat
# 4    https://www.espncricinfo.com/cricketers/gerhar...  Right hand Bat
# ..                                                 ...             ...
# 208  https://www.espncricinfo.com/cricketers/ashton...   Left hand Bat
# 209  https://www.espncricinfo.com/cricketers/brando...  Right hand Bat
# 210  https://www.espncricinfo.com/cricketers/shorif...   Left hand Bat
# 211  https://www.espncricinfo.com/cricketers/ebadot...  Right hand Bat
# 212  https://www.espncricinfo.com/cricketers/chris-...  Right hand Bat
#
#                                 bowlingStyle         playingRole
# 0    Left arm Medium, Slow Left arm Orthodox  Bowling Allrounder
# 1                                   Legbreak      Opening Batter
# 2                 Right arm Medium, Legbreak              Batter
# 3                      Right arm Medium fast              Batter
# 4                         Right arm Offbreak          Allrounder
# ..                                       ...                 ...
# 208                   Slow Left arm Orthodox              Bowler
# 209                           Right arm Fast              Bowler
# 210                     Left arm Medium fast              Bowler
# 211                    Right arm Fast medium              Bowler
# 212                    Right arm Fast medium              Bowler
#
# [213 rows x 6 columns]

# %%
#saving the playerinfo dataframe as csv

df_player_info.to_csv(r"Data\player_info.csv",index=False)
